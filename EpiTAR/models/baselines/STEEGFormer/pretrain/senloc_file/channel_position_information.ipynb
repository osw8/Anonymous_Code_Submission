# %% [markdown]
# # A simple tutorial on how to prepare your dataset's channel indices

# %%
import pickle
import numpy as np
import mne
mi_channels = ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1',
                'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7',
                'P9', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8',
                'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT8', 'FC6', 'FC4', 'FC2', 'FCz',
                'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8',
                'P10', 'PO8', 'PO4', 'O2']

large_im_channels = ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'A1', 'A2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz']

bci_comp_iv2a_channels = ['Fz', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4','C6', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'P1', 'Pz', 'P2', 'POz']

bci_comp_iv2b_channels = ['C3', 'Cz', 'C4']

bci_meditation_channels = ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT7', 'FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'FT8', 'T7', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP7', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'TP8', 'P7', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'P8', 'PO7', 'PO5', 'PO3', 'POz', 'PO4', 'PO6', 'PO8', 'I1', 'O1', 'Oz', 'O2', 'I2']

hgd_channels = ['Fp1','Fp2','Fpz','F7','F3','Fz','F4','F8','FC5','FC1','FC2','FC6','M1','T7','C3','Cz','C4','T8','M2','CP5','CP1',
 'CP2','CP6','P7','P3','Pz','P4','P8','POz','O1','Oz','O2','AF7','AF3','AF4','AF8','F5','F1','F2','F6','FC3','FCz','FC4','C5','C1',
'C2','C6','CP3','CPz','CP4','P5','P1','P2','P6','PO5','PO3','PO4','PO6','FT7','FT8','TP7','TP8','PO7','PO8','FT9','FT10','TPP9h','TPP10h','PO9','PO10','P9','P10','AFF1','AFz','AFF2','FFC5h','FFC3h','FFC4h','FFC6h','FCC5h','FCC3h','FCC4h','FCC6h','CCP5h','CCP3h','CCP4h',
 'CCP6h','CPP5h','CPP3h','CPP4h','CPP6h','PPO1','PPO2','I1','Iz','I2','AFp3h','AFp4h','AFF5h','AFF6h','FFT7h','FFC1h','FFC2h',
 'FFT8h','FTT9h','FTT7h','FCC1h','FCC2h','FTT8h','FTT10h','TTP7h','CCP1h','CCP2h','TTP8h','TPP7h','CPP1h','CPP2h','TPP8h','PPO9h','PPO5h',
 'PPO6h','PPO10h','POO9h','POO3h','POO4h','POO10h','OI1h','OI2h']

# %%
all_channels = mi_channels+large_im_channels+bci_comp_iv2a_channels+bci_comp_iv2b_channels+bci_meditation_channels+hgd_channels

# %%
unique_channels= set(all_channels)
len(unique_channels)
# Out:
# 134

# %%
channel_to_indice_dict = {}
chan_ind = 0
for chan in unique_channels:
    channel_to_indice_dict[chan] = chan_ind
    chan_ind+=1

# %%
mi_channel_ind = np.array([channel_to_indice_dict[p] for p in mi_channels])
large_im_channel_ind = np.array([channel_to_indice_dict[p] for p in large_im_channels])
bci_iv2a_channel_ind = np.array([channel_to_indice_dict[p] for p in bci_comp_iv2a_channels])
bci_comp_iv2b_channel_ind = np.array([channel_to_indice_dict[p] for p in bci_comp_iv2b_channels])
bci_meditation_channel_ind = np.array([channel_to_indice_dict[p] for p in bci_meditation_channels])
hgd_channel_ind = np.array([channel_to_indice_dict[p] for p in hgd_channels])

# %%
channel_dict = {}
channel_dict["channels_mapping"] = channel_to_indice_dict
channel_dict["bci_comp_iv2a"] = bci_iv2a_channel_ind
channel_dict["bci_comp_iv2b"] = bci_comp_iv2b_channel_ind
channel_dict["eeg_mi_bci"] = mi_channel_ind
channel_dict["large_im"] = large_im_channel_ind
channel_dict["bci_meditation"] = bci_meditation_channel_ind
channel_dict["hgd"] = hgd_channel_ind

# %%
with open("senloc_file/sen_chan_idx.pkl", 'wb') as file:
    pickle.dump(channel_dict, file)

# %%
import pickle
with open("senloc_file/sen_chan_idx.pkl", 'rb') as file:
    all_senloc = pickle.load(file)

all_senloc.keys()
# Out:
# dict_keys(['channels_mapping', 'bci_comp_iv2a', 'bci_comp_iv2b', 'eeg_mi_bci', 'large_im', 'bci_meditation', 'hgd', 'ssvep', 'auditory', 'seed'])

# %%
with open("senloc_file/sen_chan_idx.pkl", 'rb') as file:
    all_senloc = pickle.load(file)

all_senloc
